# %%
# import libraries

from bs4 import BeautifulSoup
import requests
import smtplib
import time
import datetime
import csv
import pandas as pd

# %%
# connect to website

URL = 'https://www.amazon.com.au/dp/B0B8MVJ9FM/ref=redir_mobile_desktop?_encoding=UTF8&aaxitk=76c67e1b7831a6a8e63eba1c2f651145&content-id=amzn1.sym.ec15fb94-28be-4b64-ba53-37338c6c1c62%3Aamzn1.sym.ec15fb94-28be-4b64-ba53-37338c6c1c62&hsa_cr_id=7777109900803&pd_rd_plhdr=t&pd_rd_r=2284a49b-7a12-4cf6-aa79-f6de92f6a1c7&pd_rd_w=aIyUT&pd_rd_wg=fz7qY&qid=1667866749&ref_=sbx_be_s_sparkle_mcd_asin_0_img&sr=1-1-b80f50f1-2970-4daf-ab14-5b4b5496c56c'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36", "Accpet-Encoding":"gzip, deflate", "Accept":"text/html, application/xml;q=0.9,*/*:q=0.8", "DNT":"1", "Connection":"close", "Upgrade-Insecure-Requests":"1"}
response = requests.get(URL)
soup = BeautifulSoup(response.text)

# %%
# get title
rawTitle = soup.find(id='productTitle').get_text()
title = rawTitle.strip()
print(title)
# Out:
# Samsung Galaxy Z Fold 4 5G, 512GB, Phantom Black

# %%
# get price
rawPrice = soup.find(id="corePrice_feature_div").get_text()
price1, price, price = rawPrice.split('$')
print(price)
# Out:
# 2,459.00

# %%
# get brand
rawBrand = soup.find(class_="a-spacing-small po-brand").get_text()
tmp, brand = rawBrand.strip().split()
print(brand)
# Out:
# Samsung

# %%
# get memory size
rawMemory = soup.find(class_="a-spacing-small po-memory_storage_capacity").get_text()
tmp, memory = rawMemory.strip().split('city')
print(memory)
# Out:
#    512 GB

# %%
# get screen size
rawScreenSize = soup.find(class_="a-spacing-small po-display.size").get_text()
tmp, screenSize = rawScreenSize.strip().split('size')
print(screenSize)
# Out:
#    6.2 Inches

# %%
# get system
rawSystem = soup.find(class_="a-spacing-small po-operating_system").get_text()
tmp, system = rawSystem.strip().split('System')
print(system)
# Out:
#    Android 10

# %%
# get colour
rawColour = soup.find(class_="a-spacing-small po-color").get_text()
tmp, colour = rawColour.strip().split('our')
print(colour)
# Out:
#    Phantom Black

# %%
# get date(today)
today = datetime.date.today()
print(today)
# Out:
# 2022-11-08

# %%
# create a csv file to save data
header = ['Title','Price','Brand', 'Memory size', 'Screen Size', 'Opreating System', 'Colour','Date']
data = [title, price, brand, memory, screenSize, system, colour, today]

# with open('AmazonPhoneDataset.csv', 'w', newline='',encoding='UTF8') as f:
#   writer = csv.writer(f)
#   writer.writerow(header)
#   writer.writerow(data)

# %%
df = pd.read_csv('/content/AmazonPhoneDataset.csv')
df.head()
# Out:
#                                               Title       Price    Brand  \
# 0  Samsung Galaxy Z Fold 4 5G, 512GB, Phantom Black  2,459.00    Samsung
#
#   Memory size    Screen Size Opreating System            Colour        Date
# 0      512 GB     6.2 Inches       Android 10     Phantom Black  2022-11-08

# %%
# appending data to csv

with open('AmazonPhoneDataset.csv', 'a+', newline='',encoding='UTF8') as f:
  writer = csv.writer(f)
  writer.writerow(data)

# %%
# a function for price checking
def check_price():
  URL = 'https://www.amazon.com.au/dp/B0B8MVJ9FM/ref=redir_mobile_desktop?_encoding=UTF8&aaxitk=76c67e1b7831a6a8e63eba1c2f651145&content-id=amzn1.sym.ec15fb94-28be-4b64-ba53-37338c6c1c62%3Aamzn1.sym.ec15fb94-28be-4b64-ba53-37338c6c1c62&hsa_cr_id=7777109900803&pd_rd_plhdr=t&pd_rd_r=2284a49b-7a12-4cf6-aa79-f6de92f6a1c7&pd_rd_w=aIyUT&pd_rd_wg=fz7qY&qid=1667866749&ref_=sbx_be_s_sparkle_mcd_asin_0_img&sr=1-1-b80f50f1-2970-4daf-ab14-5b4b5496c56c'
  headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36", "Accpet-Encoding":"gzip, deflate", "Accept":"text/html, application/xml;q=0.9,*/*:q=0.8", "DNT":"1", "Connection":"close", "Upgrade-Insecure-Requests":"1"}
  response = requests.get(URL)
  soup = BeautifulSoup(response.text)
  # get features
  rawTitle = soup.find(id='productTitle').get_text()
  title = rawTitle.strip()
  rawPrice = soup.find(id="corePrice_feature_div").get_text()
  price1, price, price = rawPrice.split('$')
  rawBrand = soup.find(class_="a-spacing-small po-brand").get_text()
  tmp, brand = rawBrand.strip().split()
  rawMemory = soup.find(class_="a-spacing-small po-memory_storage_capacity").get_text()
  tmp, memory = rawMemory.strip().split('city')
  rawScreenSize = soup.find(class_="a-spacing-small po-display.size").get_text()
  tmp, screenSize = rawScreenSize.strip().split('size')
  rawSystem = soup.find(class_="a-spacing-small po-operating_system").get_text()
  tmp, system = rawSystem.strip().split('System')
  rawColour = soup.find(class_="a-spacing-small po-color").get_text()
  tmp, colour = rawColour.strip().split('our')
  today = datetime.date.today()

  header = ['Title','Price','Brand', 'Memory size', 'Screen Size', 'Opreating System', 'Colour','Date']
  data = [title, price, brand, memory, screenSize, system, colour, today]
  with open('AmazonPhoneDataset.csv', 'a+', newline='',encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
#
while(True):
  check_price()
  time.sleep(84600)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-5fccd32689a8> in <module>
#       2 while(True):
#       3   check_price()
# ----> 4   time.sleep(5)
#
# KeyboardInterrupt:

# %%
df = pd.read_csv('/content/AmazonPhoneDataset.csv')
df.head()
# Out:
#                                               Title       Price    Brand  \
# 0  Samsung Galaxy Z Fold 4 5G, 512GB, Phantom Black  2,459.00    Samsung
# 1  Samsung Galaxy Z Fold 4 5G, 512GB, Phantom Black  2,459.00    Samsung
# 2  Samsung Galaxy Z Fold 4 5G, 512GB, Phantom Black  2,459.00    Samsung
# 3  Samsung Galaxy Z Fold 4 5G, 512GB, Phantom Black  2,459.00    Samsung
# 4  Samsung Galaxy Z Fold 4 5G, 512GB, Phantom Black  2,459.00    Samsung
#
#   Memory size    Screen Size Opreating System            Colour        Date
# 0      512 GB     6.2 Inches       Android 10     Phantom Black  2022-11-08
# 1      512 GB     6.2 Inches       Android 10     Phantom Black  2022-11-08
# 2      512 GB     6.2 Inches       Android 10     Phantom Black  2022-11-08
# 3      512 GB     6.2 Inches       Android 10     Phantom Black  2022-11-08
# 4      512 GB     6.2 Inches       Android 10     Phantom Black  2022-11-08
